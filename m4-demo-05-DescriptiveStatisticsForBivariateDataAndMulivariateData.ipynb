# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import scipy
import numpy as np
import pandas as pd
import seaborn as sns

from scipy import stats
import statsmodels as sm
# import statsmodels.formula.api as sm .api
import matplotlib.pyplot as plt

# %% [markdown]
# <b>Dataset: </b> https://www.kaggle.com/altavish/boston-housing-dataset

# %% [markdown]
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per dollar 10,000
# * PTRATIO - pupil-teacher ratio by town
# * LSTAT - lower status of the population-percentage
# * MEDV - Median value of owner-occupied homes in $1000's

# %%
house_data = pd.read_csv('datasets/HousingData.csv')

house_data.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
house_data.shape
# Out:
# (506, 14)

# %%
house_data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
house_data = house_data.drop(['CRIM', 'B'], axis=1)

house_data.head()
# Out:
#      ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  LSTAT  \
# 0  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98
# 1   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14
# 2   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8   4.03
# 3   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94
# 4   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7    NaN
#
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
house_data.isnull().sum()
# Out:
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
house_data.dropna(inplace=True, axis=0)

# %%
house_data.shape
# Out:
# (413, 12)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
median_price = scipy.median(house_data['MEDV'])

median_price
# Out:
# 21.2

# %%
house_data['above_median'] = np.where(house_data['MEDV'] > median_price, 1, 0)

house_data.sample(10)
# Out:
#        ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  LSTAT  \
# 11   12.5   7.87   0.0  0.524  6.009   82.9  6.2267    5  311     15.2  13.27
# 83   25.0   4.86   0.0  0.426  6.167   46.7  5.4007    4  281     19.0   7.51
# 229   0.0   6.20   0.0  0.504  6.552   21.4  3.3751    8  307     17.4   3.76
# 145   0.0  19.58   0.0  0.871  6.130  100.0  1.4191    5  403     14.7  27.80
# 149   0.0  19.58   0.0  0.871  5.597   94.9  1.5257    5  403     14.7  21.45
# 153   0.0  19.58   0.0  0.871  5.709   98.5  1.6232    5  403     14.7  15.79
# 287  52.5   5.32   0.0  0.405  6.209   31.3  7.3172    6  293     16.6   7.14
# 34    0.0   8.14   0.0  0.538  6.096   96.9  3.7598    4  307     21.0  20.34
# 420   0.0  18.10   0.0  0.718  6.411  100.0  1.8589   24  666     20.2  15.02
# 341  35.0   1.52   0.0  0.442  7.241   49.3  7.0379    1  284     15.5   5.49
#
#      MEDV  above_median
# 11   18.9             0
# 83   22.9             1
# 229  31.5             1
# 145  13.8             0
# 149  15.4             0
# 153  19.4             0
# 287  23.2             1
# 34   13.5             0
# 420  16.7             0
# 341  32.7             1

# %%
house_data.to_csv('datasets/house_data_processed.csv', index = False)

# %%
# %ls datasets\
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 76ED-0B4B
#
#  Directory of C:\Users\Sillians\Downloads\Practical data science works\interpreting-data-descriptive-statistics-python\datasets
#
# 10/12/2019  12:54 PM    <DIR>          .
# 10/12/2019  12:54 PM    <DIR>          ..
# 10/12/2019  12:54 PM             6,148 .DS_Store
# 10/12/2019  04:11 AM    <DIR>          .ipynb_checkpoints
# 10/10/2019  08:42 PM             8,318 500_Person_Gender_Height_Weight_Index.csv
# 04/09/2020  09:13 PM            11,888 automobile_data_processed.csv
# 10/10/2019  08:42 PM            18,131 auto-mpg.csv
# 04/10/2020  12:35 AM            28,220 house_data_processed.csv
# 10/10/2019  08:42 PM            35,008 HousingData.csv
# 10/10/2019  08:42 PM            24,718 Mall_Customers.json
# 04/08/2020  11:00 PM            12,452 mall_data_column_oriented.json
# 04/08/2020  11:01 PM            24,305 mall_data_index_oriented.json
# 04/08/2020  10:52 PM             5,688 mall_data_processed.csv
# 04/08/2020  11:01 PM            23,215 mall_data_records_oriented.json
# 04/08/2020  11:01 PM             6,215 mall_data_values_oriented.json
# 10/12/2019  10:32 AM               554 Salary_Data.csv
# 10/10/2019  08:42 PM            19,344 sp500_1987.csv
# 09/03/2019  05:08 PM           428,120 weight-height.csv
#               15 File(s)        652,324 bytes
#                3 Dir(s)  199,776,194,560 bytes free

# %%
# !ls datasets/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### Bivariate data analysis

# %%
house_data_selected = house_data[['MEDV', 'RM', 'DIS', 'AGE']]

house_data_selected.head(10)
# Out:
#     MEDV     RM     DIS    AGE
# 0   24.0  6.575  4.0900   65.2
# 1   21.6  6.421  4.9671   78.9
# 2   34.7  7.185  4.9671   61.1
# 3   33.4  6.998  6.0622   45.8
# 5   28.7  6.430  6.0622   58.7
# 7   27.1  6.172  5.9505   96.1
# 8   16.5  5.631  6.0821  100.0
# 10  15.0  6.377  6.3467   94.3
# 11  18.9  6.009  6.2267   82.9
# 12  21.7  5.889  5.4509   39.0

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='AGE', y='MEDV', s=80, 
                data=house_data_selected)

plt.title('House Data')
# Out:
# Text(0.5, 1.0, 'House Data')

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='RM', y='MEDV', s=80, 
                data=house_data_selected)

plt.title('House Data')
# Out:
# Text(0.5, 1.0, 'House Data')

# %%
sns.pairplot(house_data_selected)

plt.show()

# %%
with sns.axes_style('white'):
    sns.jointplot(x='RM', y='MEDV', data=house_data_selected, kind='hex')
    
    plt.show()

# %%
sns.jointplot(x='AGE', y='MEDV', data=house_data_selected, kind='kde')

plt.show()

# %% [markdown]
# ### Covarience

# %%
house_data_selected_cov = np.cov(house_data_selected.T)

house_data_selected_cov
# Out:
# array([[ 8.58208309e+01,  4.67920480e+00,  5.24740037e+00,
#         -1.01087693e+02],
#        [ 4.67920480e+00,  4.84228930e-01,  3.10710909e-01,
#         -4.66159380e+00],
#        [ 5.24740037e+00,  3.10710909e-01,  4.41923295e+00,
#         -4.44951470e+01],
#        [-1.01087693e+02, -4.66159380e+00, -4.44951470e+01,
#          7.84487407e+02]])

# %% [markdown]
# ### Correlation

# %%
house_data_selected_corr = np.corrcoef(house_data_selected.T)

house_data_selected_corr
# Out:
# array([[ 1.        ,  0.72585577,  0.26944765, -0.38959102],
#        [ 0.72585577,  1.        ,  0.21240155, -0.23917516],
#        [ 0.26944765,  0.21240155,  1.        , -0.75569441],
#        [-0.38959102, -0.23917516, -0.75569441,  1.        ]])

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(house_data_selected_corr, 
            xticklabels=house_data_selected.columns, 
            yticklabels=house_data_selected.columns,
            annot=True)

plt.show()

# %% [markdown]
# ### Linear Regression

# %%
plt.figure(figsize=(12, 8))

sns.lmplot(x='RM', y='MEDV', data=house_data)

plt.title('Salary')
# Out:
# Text(0.5, 1.0, 'Salary')

# %%
slope, intercept, r_value, _, _ ,= stats.linregress(house_data['RM'], 
                                                    house_data['MEDV'])

# %%
print('R-square value', r_value**2)
# Out:
# R-square value 0.5268665920344618

# %%
print('Slope', slope)
# Out:
# Slope 9.663207871720699

# %%
print('Intercept', intercept)
# Out:
# Intercept -38.284104692129134

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='RM', y='MEDV', s=100, 
                data=house_data, label='Original')

sns.lineplot(x=house_data['RM'], 
             y=(slope * house_data['RM'] + intercept), 
             color='r', label='Fitted line')

plt.title('Salary')
# Out:
# Text(0.5, 1.0, 'Salary')

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='AGE', y='MEDV', s=80, 
                hue='RAD', data=house_data)

plt.title('House Data')
# Out:
# Text(0.5, 1.0, 'House Data')

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='RM', y='MEDV', s=80, 
                hue='RAD', data=house_data)

plt.title('House Data')
# Out:
# Text(0.5, 1.0, 'House Data')

# %%
X = house_data.drop(['MEDV', 'above_median'], axis=1)

y = house_data['MEDV']

# %%
X.head()
# Out:
#      ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  LSTAT
# 0  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98
# 1   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14
# 2   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8   4.03
# 3   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94
# 5   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7   5.21

# %%
# import statsmodels as sm
# import statsmodels.formula as sm
import statsmodels.regression.linear_model as sm

# %%
dir(sm)
# Out:
# ['GLS',
#  'GLSAR',
#  'InvalidTestWarning',
#  'OLS',
#  'OLSResults',
#  'PredictionResults',
#  'RegressionModel',
#  'RegressionResults',
#  'RegressionResultsWrapper',
#  'WLS',
#  '_ELRegOpts',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_fit_regularized_doc',
#  '_get_sigma',
#  'add_constant',
#  'base',
#  'cache_readonly',
#  'cache_writable',
#  'chain_dot',
#  'lrange',
#  'lzip',
#  'np',
#  'np_matrix_rank',
#  'optimize',
#  'pinv_extended',
#  'pred',
#  'print_function',
#  'range',
#  'resettable_cache',
#  'stats',
#  'toeplitz',
#  'warnings',
#  'wrap',
#  'yule_walker']

# %%
reg_model = sm.OLS(y, X).fit()

reg_model.params
# Out:
# ZN         0.049678
# INDUS     -0.023188
# CHAS       4.021494
# NOX       -1.909995
# RM         6.455624
# AGE       -0.014883
# DIS       -0.901907
# RAD        0.034950
# TAX       -0.009153
# PTRATIO   -0.259886
# LSTAT     -0.399164
# dtype: float64

# %%
reg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     880.3
# Date:                Fri, 10 Apr 2020   Prob (F-statistic):          1.98e-273
# Time:                        01:17:51   Log-Likelihood:                -1239.2
# No. Observations:                 413   AIC:                             2500.
# Df Residuals:                     402   BIC:                             2545.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ZN             0.0497      0.016      3.175      0.002       0.019       0.080
# INDUS         -0.0232      0.071     -0.325      0.746      -0.164       0.117
# CHAS           4.0215      0.975      4.126      0.000       2.106       5.937
# NOX           -1.9100      3.804     -0.502      0.616      -9.388       5.568
# RM             6.4556      0.349     18.522      0.000       5.770       7.141
# AGE           -0.0149      0.015     -0.968      0.334      -0.045       0.015
# DIS           -0.9019      0.212     -4.260      0.000      -1.318      -0.486
# RAD            0.0349      0.067      0.519      0.604      -0.097       0.167
# TAX           -0.0092      0.004     -2.157      0.032      -0.017      -0.001
# PTRATIO       -0.2599      0.118     -2.206      0.028      -0.492      -0.028
# LSTAT         -0.3992      0.055     -7.308      0.000      -0.507      -0.292
# ==============================================================================
# Omnibus:                      151.948   Durbin-Watson:                   1.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              961.391
# Skew:                           1.426   Prob(JB):                    1.72e-209
# Kurtosis:                       9.909   Cond. No.                     7.04e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
